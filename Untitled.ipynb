# %%
import pandas as pd

# %%
store = pd.HDFStore('../0.h5')

# %%
test = store.get_storer('tracks').nrows

# %%
chunk = store.select('jets', start = 0, stop = 1)

# %%
store.close()

# %%
pd.read_hdf('../0.h5', key = 'jets', start = 10, stop = 20)
# Out:
#     Jet_jetIndex      Jet_pt   Jet_genpt   Jet_eta   Jet_phi   Jet_mass  \
# 10            10   33.794209   42.376511  0.646752  2.916097   4.635757
# 11            11   29.634102   27.482023 -1.092201 -1.847709   5.526241
# 12            12   22.369608   21.959921 -0.013586  2.285115   4.104486
# 13            13   20.984880   23.567837 -0.216252  0.612154   3.245879
# 14            14  111.533165  106.700966 -1.242061  0.656113  11.278137
# 15            15   78.682678   90.928658 -0.541593  2.855596  13.586503
# 16            16   62.927746   54.594231  1.047810 -1.411328  12.042562
# 17            17   46.742874   40.937336 -1.313937  2.646595   7.587672
# 18            18   29.707779   25.386944 -0.328662 -1.071120   6.868381
# 19            19  105.522942  100.921181 -0.572873  1.737130   8.502139
#
#     Jet_flavour  Jet_nbHadrons    Jet_JP   Jet_JBP           ...             \
# 10         21.0            0.0  0.539976  2.172424           ...
# ...
