# %%
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt

# %%
# use for reference job id 6453519
random = np.load("./shallow_out/6453519/ROC.pdfrandom_classifier.np.npy")
RNN = np.load("./RNN_out/7556430/ROC.npy")

# %%
plt.plot(random[1,:], random[0,:], label = "random")
plt.plot(RNN[1,:], RNN[1,:], label = "RNN")
plt.yscale('log')
axes = plt.gca()
axes.set_ylim([1e-2,1])
plt.legend(loc = "upper left")
plt.xlabel('b jet efficiency')
plt.ylabel('misidentification prob.')
plt.show()
