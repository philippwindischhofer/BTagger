# %%
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt

# %%
test = np.load("RNN_ROC.npy")

# %%
plt.plot(test[1,:], test[0,:])
plt.yscale('log')
axes = plt.gca()
axes.set_ylim([1e-2,1])
plt.xlabel('b jet efficiency')
plt.ylabel('misidentification prob.')
plt.show()
